# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Reading the CSV file

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\dsbdl practical\DSBDA-practical--main\Assignments\iris.csv")
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
df["Species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.groupby("Species").size()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# ### List down the features and their types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Create a histogram for each feature in the dataset.

# %%
corr = df.corr()
plt.subplots(figsize=(10,6))
sns.heatmap(corr, annot=True,cmap="coolwarm")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1376\2230858217.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >

# %% [markdown]
# ### Create a box plot for each feature in the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt


column_names =df.columns

c="pink"
# Step 2: Create a histogram for each feature
df.hist(color=c, figsize=(10, 8))


plt.show()

# %%
import matplotlib.pyplot as plt

def graph(y):
    sns.boxplot(x="Species",y=y,data=df)
plt.figure(figsize=(10,6))
column_names1 =df.columns
plt.subplot(221)
graph('Sepal.Width')
plt.subplot(222)
graph('Sepal.Length')
plt.subplot(223)
graph('Petal.Width')
plt.subplot(224)
graph('Petal.Length')

# %% [markdown]
# ### Compare distributions and identify outliers.

# %%
sns.boxplot(x='SepalWidthCm', data=df)
plt.show()
sns.boxplot(x='SepalLengthCm', data=df)
plt.show()
sns.boxplot(x='PetalWidthCm', data=df)
plt.show()
sns.boxplot(x='PetalLengthCm', data=df)
plt.show()
